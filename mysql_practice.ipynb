# %%
import mysql.connector as con
mydb = con.connect(
host ="localhost",
user = "root",
password = "9876",
database = "matrimony"    
)
mycursor = mydb.cursor()
mycursor.execute("select * from `profiles` WHERE monthly_income>'10000' and gender='ஆண்'")
for i in mycursor:
    print(i)
# Out:
# (10100, 'B', 'ஆண்', 'A', '293', '1', '', 'N', 'A', 'சிவா', '', '', '', 'MBBS MS (Ortho)', 'Medical', 'சொந்த கிளினிக்', 'Business', 'சென்னை', '', '100000', '99458', '0', '', '5-1-2019', 'சென்னை', '', '30-9-1985', '1', '12:35', 'AM', '', '', '7', '5.9', '', '1', 0, '', 'first', '', '', '', '1', '', '', '', '', '', 'சென்னை', 'கடலூர்', 'சென்னை', '', 'ஏழும\u200cல\u200cை\u200c', '', 'GOVT (RTED)', 'அமுதா', '', 'House wife', '2', 'சென்னை டாக்டர் பையன்', '2', 'http://luisantsoftwares.com/mangalam/uploads/1574657611.png', '', '', '', '', '1', '', '', '', '', '', 'வீடு உண்டு கார் உண்டு', '', '453', '766', '', '', '', '', '', '27', '2', '', '12', '', '', '', '', '', 'N', '', '', 45, 45, 'டாக்டர் பெண்', '1', '', '', '1', datetime.datetime(2019, 1, 5, 8, 15, 42), datetime.datetime(2019, 2, 9, 8, 11, 18), 1, '', 'Enable', '10987.jpeg')
# ...
